# %% [markdown]
# ## Algebra Linear
# ![imagem.webp](attachment:imagem.webp)
# - A álgebra linear consiste no estudo dos espaços vetoriais e das transformações lineares entre eles. Vetores, transformações lineares, matrizes e formas quadráticas são temas muito importantes dessa área no ensino da matemática.
